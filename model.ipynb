# %% [markdown]
# # **Predicting Teamfight Tactics Results with Machine Learning Techniques**
#
# Teamfight Tactics (TFT) is an online auto-battler from Riot Games. With such a vast playerbase, this game generates massive amounts of data which as mentioned in Introduction is a den for testing ML techniques to predict an outcome of a game.
#
# The project explores the relationships between different augments, champions and items within a team as a decisive factor in a win rather just the team composition. Hence, from supervised learning, there were implemented regression models to predict a continuous variable (placement) and classification models to predict a discrete variable (win/loss). The objective is to find which model has the best accuracy.

# %% [markdown]
# ## **Setting up**
#
# ### **Import needed libraries**

# %%
import pandas as pd
from sklearn.decomposition import PCA as sklearnPCA
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# Model Select
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.linear_model import  LogisticRegression, LinearRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score, mean_squared_error, r2_score
from sklearn.svm import SVC, SVR

# %% [markdown]
# ### **Load Data**

# %%
data = pd.read_csv('data/final.csv')

# %% [markdown]
# ## **Analyze Data**
#
# ### **Check missing values**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9592 entries, 0 to 9591
# Columns: 435 entries, level to placement
# dtypes: int64(435)
# memory usage: 31.8 MB

# %%
# Check for missing values
missing_values = data.isnull().sum().sum()

# Display any missing values
missing_values
# Out:
# 0

# %% [markdown]
# ### **Target (Placement) distribution**

# %%
#   
plt.figure(figsize=(10, 6))
sns.histplot(data['placement'], bins=8, kde=False)
plt.title('Distribution of Placement')
plt.xlabel('Placement')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# The histogram of the placement column shows a fairly uniform distribution across different placement ranks from 1 to 8, which suggests that the data covers all placement outcomes well.

# %% [markdown]
# ### **Correlation heatmap**

# %%
# Calculate the correlation matrix
corr_matrix = data.corr()

# Get the absolute correlation values with 'placement'
correlation_with_placement = corr_matrix['placement'].abs()

# Sort the attributes by decreasing correlation values, excluding 'placement'
sorted_correlation = correlation_with_placement.sort_values(ascending=False)

# Select the top 30 features, including 'placement'
top_features = sorted_correlation.index[:30]

# Creat new correlation heatmap 
corr_matrix_cleaned = corr_matrix.loc[top_features, top_features]

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix_cleaned, cmap='coolwarm', linewidths=0.1, annot=True, fmt=".1f")
plt.title('Correlation Heatmap of Top 30 Features Related to Placement')
plt.show()

# %%
# Find the top 10 features that correlate most strongly with 'placement'
top_correlations = corr_matrix_cleaned['placement'].abs().sort_values(ascending=False).head(11)

# Show the top correlating features
top_correlations
# Out:
# placement        1.000000
# level            0.537287
# WuKong           0.261975
# Rakan            0.213714
# Irelia           0.197702
# Udyr             0.187076
# Hwei             0.177519
# Lissandra        0.152256
# Sett             0.142115
# Thiefs Gloves    0.131904
# Dragonlord.1     0.127664
# Name: placement, dtype: float64

# %%
# Initialize a dictionary to store the top correlated features for each feature
top_correlated_pairs = {}

# Loop through each column in the correlation matrix
for feature in corr_matrix_cleaned.columns:
    # Get the absolute correlation values with other features
    correlations = corr_matrix_cleaned[feature].sort_values(ascending=False)
    
    # Exclude the feature itself
    correlations = correlations.drop(index=feature)
    
    # Select the top 5 correlated features
    top_correlated_pairs[feature] = correlations.head(5)

# Display the top correlated pairs for each feature
for feature, top_correlated in top_correlated_pairs.items():
    print(f"Top 5 correlated features with '{feature}':")
    print(top_correlated)
    print()
# Out:
# Top 5 correlated features with 'placement':
# Behemoth.1          -0.080134
# Xayah               -0.083053
# Steraks Gage        -0.083536
# Runaans Hurricane   -0.083704
# Statikk Shiv        -0.085782
# Name: placement, dtype: float64
#
# Top 5 correlated features with 'level':
# WuKong    0.379071
# Rakan     0.365003
# Hwei      0.315028
# Udyr      0.312024
# Irelia    0.303216
# Name: level, dtype: float64
#
# Top 5 correlated features with 'WuKong':
# Sage.1          0.571906
# Rakan           0.505090
# Heavenly.1      0.437840
# Dragonlord.1    0.427698
# Diana           0.403552
# Name: WuKong, dtype: float64
#
# Top 5 correlated features with 'Rakan':
# Altruist        0.658131
# Dragonlord.1    0.617157
# WuKong          0.505090
# Irelia          0.452110
# Diana           0.437989
# Name: Rakan, dtype: float64
#
# Top 5 correlated features with 'Irelia':
# LeeSin          0.566008
# Dragonlord.1    0.477686
# Rakan           0.452110
# WuKong          0.385315
# Altruist        0.369623
# Name: Irelia, dtype: float64
#
# Top 5 correlated features with 'Udyr':
# Behemoth.1    0.429406
# Azir          0.332082
# level         0.312024
# Hwei          0.255847
# WuKong        0.201805
# Name: Udyr, dtype: float64
#
# Top 5 correlated features with 'Hwei':
# Rakan           0.398343
# Azir            0.378859
# WuKong          0.340562
# level           0.315028
# Dragonlord.1    0.274211
# Name: Hwei, dtype: float64
#
# Top 5 correlated features with 'Lissandra':
# level    0.257516
# Sett     0.147780
# Udyr     0.115136
# Rakan    0.110435
# Hwei     0.106217
# Name: Lissandra, dtype: float64
#
# Top 5 correlated features with 'Sett':
# Behemoth.1           0.228631
# level                0.185267
# Lissandra            0.147780
# Steraks Gage         0.068799
# Rapid Fire Cannon    0.057656
# Name: Sett, dtype: float64
#
# Top 5 correlated features with 'Thiefs Gloves':
# Steraks Gage         0.136262
# Runaans Hurricane    0.130844
# level                0.114429
# Statikk Shiv         0.106313
# Rapid Fire Cannon    0.093348
# Name: Thiefs Gloves, dtype: float64
#
# Top 5 correlated features with 'Dragonlord.1':
# Diana     0.762082
# LeeSin    0.674569
# Rakan     0.617157
# Sage.1    0.542766
# Irelia    0.477686
# Name: Dragonlord.1, dtype: float64
#
# Top 5 correlated features with 'Altruist':
# Soraka          0.675201
# Rakan           0.658131
# Dragonlord.1    0.446714
# WuKong          0.381587
# Irelia          0.369623
# Name: Altruist, dtype: float64
#
# Top 5 correlated features with 'Sage.1':
# Diana           0.650987
# WuKong          0.571906
# Dragonlord.1    0.542766
# Rakan           0.404757
# Altruist        0.362798
# Name: Sage.1, dtype: float64
#
# Top 5 correlated features with 'Soraka':
# Altruist        0.675201
# Heavenly.1      0.553743
# Rakan           0.405399
# WuKong          0.396812
# Dragonlord.1    0.269406
# Name: Soraka, dtype: float64
#
# Top 5 correlated features with 'Heavenly.1':
# Soraka      0.553743
# WuKong      0.437840
# Altruist    0.193437
# Rakan       0.173890
# Irelia      0.137764
# Name: Heavenly.1, dtype: float64
#
# Top 5 correlated features with 'Madreds Bloodrazor':
# level            0.112849
# Thiefs Gloves    0.084845
# Irelia           0.079166
# Udyr             0.066954
# LeeSin           0.062809
# Name: Madreds Bloodrazor, dtype: float64
#
# Top 5 correlated features with 'Azir':
# Hwei      0.378859
# Udyr      0.332082
# Rakan     0.303988
# WuKong    0.261073
# level     0.245917
# Name: Azir, dtype: float64
#
# Top 5 correlated features with 'Guardian Angel':
# WuKong           0.102748
# Heavenly.1       0.100817
# Thiefs Gloves    0.091791
# level            0.078283
# Sage.1           0.050456
# Name: Guardian Angel, dtype: float64
#
# Top 5 correlated features with 'LeeSin':
# Dragonlord.1    0.674569
# Irelia          0.566008
# Diana           0.531401
# Rakan           0.353165
# Sage.1          0.327718
# Name: LeeSin, dtype: float64
#
# Top 5 correlated features with 'Ionic Spark':
# Behemoth.1       0.143215
# Udyr             0.115593
# level            0.073406
# Azir             0.070754
# Thiefs Gloves    0.062310
# Name: Ionic Spark, dtype: float64
#
# Top 5 correlated features with 'Rapid Fire Cannon':
# Thiefs Gloves    0.093348
# level            0.086715
# Irelia           0.083880
# Sett             0.057656
# LeeSin           0.054541
# Name: Rapid Fire Cannon, dtype: float64
#
# Top 5 correlated features with 'Exalted.1':
# level                 0.129951
# Sage.1                0.033168
# Azir                  0.025524
# Madreds Bloodrazor    0.025109
# Adaptive Helm         0.022575
# Name: Exalted.1, dtype: float64
#
# Top 5 correlated features with 'Adaptive Helm':
# level            0.100903
# Thiefs Gloves    0.091170
# Hwei             0.087669
# Azir             0.079459
# Udyr             0.075274
# Name: Adaptive Helm, dtype: float64
#
# Top 5 correlated features with 'Diana':
# Dragonlord.1    0.762082
# Sage.1          0.650987
# LeeSin          0.531401
# Rakan           0.437989
# WuKong          0.403552
# Name: Diana, dtype: float64
#
# Top 5 correlated features with 'Crownguard':
# Udyr                  0.084713
# Thiefs Gloves         0.073677
# level                 0.064098
# Madreds Bloodrazor    0.040661
# Behemoth.1            0.039381
# Name: Crownguard, dtype: float64
#
# Top 5 correlated features with 'Statikk Shiv':
# Hwei             0.138292
# Azir             0.130381
# level            0.109494
# Thiefs Gloves    0.106313
# Udyr             0.103479
# Name: Statikk Shiv, dtype: float64
#
# Top 5 correlated features with 'Runaans Hurricane':
# LeeSin           0.163210
# Irelia           0.148635
# Thiefs Gloves    0.130844
# Dragonlord.1     0.096312
# Diana            0.089684
# Name: Runaans Hurricane, dtype: float64
#
# Top 5 correlated features with 'Steraks Gage':
# Thiefs Gloves     0.136262
# level             0.072859
# Sett              0.068799
# WuKong            0.063996
# Guardian Angel    0.045081
# Name: Steraks Gage, dtype: float64
#
# Top 5 correlated features with 'Xayah':
# Udyr                  0.152951
# level                 0.112218
# Runaans Hurricane     0.041326
# Madreds Bloodrazor    0.040177
# Crownguard            0.020868
# Name: Xayah, dtype: float64
#
# Top 5 correlated features with 'Behemoth.1':
# Udyr           0.429406
# Sett           0.228631
# level          0.163080
# Azir           0.159579
# Ionic Spark    0.143215
# Name: Behemoth.1, dtype: float64

# %% [markdown]
# ## **Preparation Data**

# %%
# Convert 'placement' into binary classification target
# 1-4 will be 1 ('win'), 5-8 will be 0 ('loss')
data['placement'] = data['placement'].apply(lambda x: 1 if x <= 4 else 0)   

# Define features (X) and target (y)
X = data.drop(columns=['placement'])
y = data['placement']

# %% [markdown]
# **Training and Test sets**

# %%
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=32)

# %% [markdown]
# **Visualize fuction**

# %%
total_variance_retained = 0 
k = 2
while total_variance_retained < 80:
    k+=1
    pca = PCA(n_components=k)
    pca.fit(X)
    # Lấy tỷ lệ phương sai giữ lại của các thành phần chính
    explained_variance_ratio = pca.explained_variance_ratio_
    
    # Tính tổng phần trăm thông tin giữ lại
    total_variance_retained = sum(explained_variance_ratio) * 100    
print(f"Tổng phần trăm thông tin giữ lại:{total_variance_retained:.02f}%")
print(f"Số chiều:{k}/{len(X.columns)}")

pca = PCA(n_components=2)
pca_data = pca.fit_transform(X)
# Lấy tỷ lệ phương sai giữ lại của các thành phần chính
explained_variance_ratio = pca.explained_variance_ratio_

# Tính tổng phần trăm thông tin giữ lại
total_variance_retained = sum(explained_variance_ratio) * 100
total_variance_retained
#%%
pca_data = pd.DataFrame(pca_data)
#%%
pca_data = pd.concat([pca_data, y], axis=1)
#%%
win_group = pca_data[pca_data['placement'] == 1]
loss_group = pca_data[pca_data['placement'] == 0]
#%%
plt.figure(figsize=(10, 6))
plt.scatter(win_group.iloc[:, 0], win_group.iloc[:, 1], color='blue', label='Win (placement = 1)')
plt.scatter(loss_group.iloc[:, 0], loss_group.iloc[:, 1], color='red', label='Loss (placement = 0)')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Plot after using PCA')
plt.legend()
plt.show()
# Out:
# Tổng phần trăm thông tin giữ lại:80.02%
# Số chiều:70/434

# %% [markdown]
# ## **Classification Model**

# %% [markdown]
# ### **Naive Bayes Model**

# %%
# Initialize the models
naive_bayes_model = MultinomialNB()

# Train the Naive Bayes model
naive_bayes_model.fit(X_train, y_train)

# Predictions for Naive Bayes
y_pred_naive_bayes = naive_bayes_model.predict(X_test)

# Evaluate the Naive Bayes model
accuracy_naive_bayes = accuracy_score(y_test, y_pred_naive_bayes)
f1_naive_bayes = f1_score(y_test, y_pred_naive_bayes)

# %% [markdown]
# ### **Logistic Regression Model**

# %%
# Initialize the models
logistic_model = LogisticRegression(max_iter=1000, random_state=42)

# Train the Logistic Regression model
logistic_model.fit(X_train, y_train)

# Predictions for Logistic Regression
y_pred_logistic = logistic_model.predict(X_test)

# Evaluate the Logistic Regression model
accuracy_logistic = accuracy_score(y_test, y_pred_logistic)
f1_logistic = f1_score(y_test, y_pred_logistic)

# %% [markdown]
# ### **Support Vector Machine Model**

# %%
# Initialize the Support Vector Machine model
svm_model = SVC(random_state=42)

# Train the SVM model
svm_model.fit(X_train, y_train)

# Predictions for SVM
y_pred_svm = svm_model.predict(X_test)

# Evaluate the SVM model
accuracy_svm = accuracy_score(y_test, y_pred_svm)
f1_svm = f1_score(y_test, y_pred_svm)

# %% [markdown]
# ## **Regression Model**
#
# ### **Linear Regression Model**

# %%
# Creating a linear regression model
linear_reg = LinearRegression()

# Training the model
linear_reg.fit(X_train, y_train)

# Predicting on the test set
y_pred = linear_reg.predict(X_test)

# Calculating the mean squared error and R-squared value
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %% [markdown]
# ### **Support Vector Regression Model**

# %%
# Create and train the SVR model with a linear kernel
svr_linear = SVR(kernel='linear')
svr_linear.fit(X_train, y_train)

# Predict on the test set using SVR
y_pred_svr = svr_linear.predict(X_test)

# Calculating metrics for SVR
mse_svr = mean_squared_error(y_test, y_pred_svr)
r2_svr = r2_score(y_test, y_pred_svr)

# %%
y_pred_svr
# Out:
# array([0.55672551, 0.135472  , 0.63857888, ..., 0.67670548, 0.76845364,
#        1.30859771])

# %% [markdown]
# ### **Performance Comparison**

# %%
def calculate_errors(model, X_train, y_train, X_test, y_test):
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)
    train_error = mean_squared_error(y_train, y_train_pred)
    test_error = mean_squared_error(y_test, y_test_pred)
    return train_error, test_error

# Tính sai số cho tất cả các mô hình
train_error_logistic, test_error_logistic = calculate_errors(logistic_model, X_train, y_train, X_test, y_test)
train_error_naive_bayes, test_error_naive_bayes = calculate_errors(naive_bayes_model, X_train, y_train, X_test, y_test)
train_error_svm, test_error_svm = calculate_errors(svm_model, X_train, y_train, X_test, y_test)
train_error_linear, test_error_linear = calculate_errors(linear_reg, X_train, y_train, X_test, y_test)
train_error_svr, test_error_svr = calculate_errors(svr_linear, X_train, y_train, X_test, y_test)

print("Train and Test Errors for all models:")
print("Logistic Regression - Train Error:", train_error_logistic, "Test Error:", test_error_logistic)
print("Naive Bayes - Train Error:", train_error_naive_bayes, "Test Error:", test_error_naive_bayes)
print("SVM - Train Error:", train_error_svm, "Test Error:", test_error_svm)
print("Linear Regression - Train Error:", train_error_linear, "Test Error:", test_error_linear)
print("SVR - Train Error:", train_error_svr, "Test Error:", test_error_svr)
# Out:
# Train and Test Errors for all models:
# Logistic Regression - Train Error: 0.15933970460469157 Test Error: 0.20771436017722178
# Naive Bayes - Train Error: 0.38123370981754995 Test Error: 0.41360437842064113
# SVM - Train Error: 0.13744569939183318 Test Error: 0.19781078967943705
# Linear Regression - Train Error: 0.1367301153025645 Test Error: 0.16675395234860546
# SVR - Train Error: 0.14704761229370117 Test Error: 0.17910412282993235

# %% [markdown]
# **Conclusion:**
# All models exhibit overfitting to some extent, with SVM showing the most severe overfitting. `Linear Regression` and `SVR` have less discrepancy between Train and Test Error, indicating better generalization capability.

# %%
regression_comparison = {
    "Model": ["Linear Regression", "SVR (Linear Kernel)"],
    "MSE": [mse, mse_svr],
    "R² Score": [r2, r2_svr]
}

regression_comparison_df = pd.DataFrame(regression_comparison)

regression_comparison_df.set_index('Model').plot(kind='bar', figsize=(14, 8), width=0.8)
plt.title('Comparison of Model Performances')
plt.ylabel('Score')
plt.grid(True)
plt.xticks(rotation=0)
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# - `Linear Regression` demonstrates a relatively low MSE compared to SVR, but its R² Score is also slightly lower. This suggests that the Linear Regression model may be a better choice as it balances between effectiveness and explanatory ability.
# - `SVR` has a higher R² Score, but its MSE is significantly higher compared to Linear Regression, indicating that this model may not be as effective as Linear Regression in predicting target values.

# %%
classification_comparison = {
    'Model': ['Logistic Regression', 'Naive Bayes', 'SVM'],
    'Accuracy': [accuracy_logistic, accuracy_naive_bayes, accuracy_svm], 
    'F1 Score': [f1_logistic, f1_naive_bayes, f1_svm],  
}

performance_df = pd.DataFrame(classification_comparison)

performance_df.set_index('Model').plot(kind='bar', figsize=(14, 8), width=0.8)
plt.title('Comparison of Model Performances')
plt.ylabel('Score')
plt.grid(True)
plt.xticks(rotation=0)
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# - Logistic Regression has both Accuracy and F1 Score at a moderate level, indicating it's a fairly balanced classification model.
# - Naive Bayes has the lowest Accuracy and F1 Score among the three models, suggesting it might not be suitable for the distribution or features of the data.
# - SVM has a higher Accuracy compared to Naive Bayes, but its F1 Score is lower, indicating that while SVM may classify overall accurately, it might struggle with balancing between classes or have issues with precision in minority classes.

# %% [markdown]
# **Conclusion:**
# The `Linear Regression` model seems to be the best choice for regression tasks, while `Logistic Regression` is a good choice for classification based on current data.
